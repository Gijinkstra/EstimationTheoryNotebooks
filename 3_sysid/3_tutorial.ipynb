# %%
import numpy as np

# %% [markdown]
# **See first:** [System identification](./1_sysid_basic.ipynb)

# %% [markdown]
# ## System identification exercise
#
# Consider a system with state $x\in{\rm I\!R}^4$ and dynamics
# $$x_{t+1} = Ax_t + w_t,$$
# where $A\in{\rm I\!R}^{4\times 4}$ is an unknown matrix, and $w_t$ is a random process noise.
#
# In the file [`tutorial_data.csv`](./tutorial_data.csv) you will find a recorded sequence of states. Use this data to estimate the unknown system matrix. Evaluate the quality of your estimate.

# %%
# Your code goes here

# %% [markdown]
# Next, suppose you know that $A$ has the form
# $$A = \begin{bmatrix}
# \textcolor{red}{0.72}& ?& ?& ?\\
# ?& ?& \textcolor{red}{0}& \textcolor{red}{0}\\
# \textcolor{red}{0}& ?& ?& \textcolor{red}{0}\\
# \textcolor{red}{0}& \textcolor{red}{0}& ?& ?
# \end{bmatrix}.$$
# Estimate $A$ again using the constrained estimation approach (see [this notebook](./1_sysid_basic.ipynb)).

# %%
# Your code goes here

# %% [markdown]
# If you're really curious, the matrix I used to generate the data in `tutorial_data.csv` is the following

# %%
A_actual = np.array([[0.72, 0.21, -0.3, 0.4],
                     [0.45, 0.65, 0., 0.],
                     [0, 0.1, -0.55, 0.],
                     [0, 0, 0.1, 0.05]])

# %% [markdown]
# You can compare your estimated matrices with the actual one.
