# %%
import numpy as np

# %% [markdown]
# ## System identification exercise
#
# Consider a system with state $x\in{\rm I\!R}^4$ and dynamics
# $$x_{t+1} = Ax_t + w_t,$$
# where $A\in{\rm I\!R}^{4\times 4}$ is an unknown matrix, and $w_t$ is a random process noise.
#
# In the file [`data.csv`](./data.csv) you will find a recorded sequence of states. Use this data to estimate the unknown system matrix. Evaluate the quality of your estimate.

# %%
# Your code goes here
